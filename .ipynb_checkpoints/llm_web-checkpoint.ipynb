# %%
# pip install streamlit tiktoken
# pip install langchain

# %%
pip install streamlit.jupyter
# Out:
# Collecting streamlit.jupyter
#   Downloading streamlit_jupyter-0.3.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting fastcore (from streamlit.jupyter)
#   Downloading fastcore-1.11.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting ipywidgets>=8 (from streamlit.jupyter)
#   Downloading ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: jupyter in c:\users\user\anaconda3\lib\site-packages (from streamlit.jupyter) (1.0.0)
# Collecting stqdm (from streamlit.jupyter)
#   Downloading stqdm-0.0.5-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: streamlit>=1.19 in c:\users\user\anaconda3\lib\site-packages (from streamlit.jupyter) (1.32.0)
# Requirement already satisfied: tabulate in c:\users\user\anaconda3\lib\site-packages (from streamlit.jupyter) (0.9.0)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\lib\site-packages (from streamlit.jupyter) (4.66.4)
# Requirement already satisfied: comm>=0.1.3 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets>=8->streamlit.jupyter) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets>=8->streamlit.jupyter) (8.25.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets>=8->streamlit.jupyter) (5.14.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets>=8->streamlit.jupyter)
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets>=8->streamlit.jupyter)
#   Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\user\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit.jupyter) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit.jupyter) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\user\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit.jupyter) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\user\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit.jupyter) (8.1.7)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\user\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit.jupyter) (1.26.4)
# Requirement already satisfied: packaging<24,>=16.8 in c:\users\user\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit.jupyter) (23.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\user\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit.jupyter) (2.3.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\user\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit.jupyter) (10.3.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\user\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit.jupyter) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\user\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit.jupyter) (14.0.2)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\user\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit.jupyter) (2.32.2)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\user\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit.jupyter) (13.3.5)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\user\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit.jupyter) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\user\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit.jupyter) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\user\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit.jupyter) (4.15.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\user\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit.jupyter) (3.1.37)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\user\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit.jupyter) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\user\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit.jupyter) (6.4.1)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\user\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit.jupyter) (4.0.1)
# Requirement already satisfied: notebook in c:\users\user\anaconda3\lib\site-packages (from jupyter->streamlit.jupyter) (7.0.8)
# Requirement already satisfied: qtconsole in c:\users\user\anaconda3\lib\site-packages (from jupyter->streamlit.jupyter) (5.5.1)
# Requirement already satisfied: jupyter-console in c:\users\user\anaconda3\lib\site-packages (from jupyter->streamlit.jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\user\anaconda3\lib\site-packages (from jupyter->streamlit.jupyter) (7.10.0)
# Requirement already satisfied: ipykernel in c:\users\user\anaconda3\lib\site-packages (from jupyter->streamlit.jupyter) (6.28.0)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm->streamlit.jupyter) (0.4.6)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit>=1.19->streamlit.jupyter) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\user\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit>=1.19->streamlit.jupyter) (4.19.2)
# Requirement already satisfied: toolz in c:\users\user\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit>=1.19->streamlit.jupyter) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\user\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.19->streamlit.jupyter) (4.0.7)
# Requirement already satisfied: decorator in c:\users\user\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8->streamlit.jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8->streamlit.jupyter) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\user\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8->streamlit.jupyter) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\user\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8->streamlit.jupyter) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\user\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8->streamlit.jupyter) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\user\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8->streamlit.jupyter) (0.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit>=1.19->streamlit.jupyter) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit>=1.19->streamlit.jupyter) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit>=1.19->streamlit.jupyter) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit.jupyter) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit.jupyter) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit.jupyter) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit.jupyter) (2025.10.5)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\user\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit>=1.19->streamlit.jupyter) (2.2.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter->streamlit.jupyter) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter->streamlit.jupyter) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter->streamlit.jupyter) (5.7.2)
# Requirement already satisfied: nest-asyncio in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter->streamlit.jupyter) (1.6.0)
# Requirement already satisfied: psutil in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter->streamlit.jupyter) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter->streamlit.jupyter) (25.1.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter->streamlit.jupyter) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter->streamlit.jupyter) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter->streamlit.jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter->streamlit.jupyter) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter->streamlit.jupyter) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter->streamlit.jupyter) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter->streamlit.jupyter) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter->streamlit.jupyter) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter->streamlit.jupyter) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter->streamlit.jupyter) (1.2.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\user\anaconda3\lib\site-packages (from notebook->jupyter->streamlit.jupyter) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\user\anaconda3\lib\site-packages (from notebook->jupyter->streamlit.jupyter) (2.25.1)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in c:\users\user\anaconda3\lib\site-packages (from notebook->jupyter->streamlit.jupyter) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\user\anaconda3\lib\site-packages (from notebook->jupyter->streamlit.jupyter) (0.2.3)
# Requirement already satisfied: qtpy>=2.4.0 in c:\users\user\anaconda3\lib\site-packages (from qtconsole->jupyter->streamlit.jupyter) (2.4.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\user\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter->streamlit.jupyter) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\user\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter->streamlit.jupyter) (0.5.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\user\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.19->streamlit.jupyter) (4.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\user\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8->streamlit.jupyter) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit.jupyter) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit.jupyter) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit.jupyter) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit.jupyter) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\user\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->streamlit.jupyter) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\user\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->streamlit.jupyter) (305.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit.jupyter) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit.jupyter) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit.jupyter) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit.jupyter) (0.4.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit.jupyter) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit.jupyter) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit.jupyter) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit.jupyter) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit.jupyter) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit.jupyter) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook->jupyter->streamlit.jupyter) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook->jupyter->streamlit.jupyter) (2.2.0)
# Requirement already satisfied: babel>=2.10 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->streamlit.jupyter) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->streamlit.jupyter) (0.9.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\user\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14,>=10.14.0->streamlit>=1.19->streamlit.jupyter) (0.1.0)
# Requirement already satisfied: fastjsonschema in c:\users\user\anaconda3\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter->streamlit.jupyter) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=8->streamlit.jupyter) (0.2.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->streamlit.jupyter) (2.5)
# Requirement already satisfied: executing in c:\users\user\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8->streamlit.jupyter) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\user\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8->streamlit.jupyter) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\user\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8->streamlit.jupyter) (0.2.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\user\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit.jupyter) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\user\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit.jupyter) (21.2.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\user\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit.jupyter) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\user\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit.jupyter) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\user\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit.jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\user\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit.jupyter) (0.1.1)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit.jupyter)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit.jupyter)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\user\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit.jupyter) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit.jupyter)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=1.11 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit.jupyter)
#   Downloading webcolors-25.10.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit.jupyter) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit.jupyter) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\user\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit.jupyter) (1.2.3)
# Downloading streamlit_jupyter-0.3.1-py3-none-any.whl (13 kB)
# Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.8 kB ? eta -:--:--
#    ----------- ---------------------------- 41.0/139.8 kB 1.9 MB/s eta 0:00:01
#    -------------------------------------- - 133.1/139.8 kB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 139.8/139.8 kB 1.7 MB/s eta 0:00:00
# Downloading fastcore-1.11.3-py3-none-any.whl (89 kB)
#    ---------------------------------------- 0.0/89.1 kB ? eta -:--:--
#    ---------------------------------------- 89.1/89.1 kB 4.9 MB/s eta 0:00:00
# Downloading stqdm-0.0.5-py3-none-any.whl (11 kB)
# Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
#    ---------------------------------------- 0.0/914.9 kB ? eta -:--:--
#    ----------- ---------------------------- 256.0/914.9 kB 5.2 MB/s eta 0:00:01
#    ---------------------------------------  911.4/914.9 kB 9.6 MB/s eta 0:00:01
#    ---------------------------------------- 914.9/914.9 kB 8.2 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------- ----------------- 1.2/2.2 MB 39.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 23.5 MB/s eta 0:00:00
# Downloading webcolors-25.10.0-py3-none-any.whl (14 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: widgetsnbextension, webcolors, uri-template, jupyterlab_widgets, fqdn, fastcore, isoduration, ipywidgets, stqdm, streamlit.jupyter
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.6
#     Uninstalling widgetsnbextension-3.6.6:
#       Successfully uninstalled widgetsnbextension-3.6.6
#   Attempting uninstall: jupyterlab_widgets
#     Found existing installation: jupyterlab-widgets 1.0.0
#     Uninstalling jupyterlab-widgets-1.0.0:
#       Successfully uninstalled jupyterlab-widgets-1.0.0
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.8.1
#     Uninstalling ipywidgets-7.8.1:
#       Successfully uninstalled ipywidgets-7.8.1
# Successfully installed fastcore-1.11.3 fqdn-1.5.1 ipywidgets-8.1.8 isoduration-20.11.0 jupyterlab_widgets-3.0.16 stqdm-0.0.5 streamlit.jupyter-0.3.1 uri-template-1.3.0 webcolors-25.10.0 widgetsnbextension-4.0.15
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
from streamlit_jupyter import StreamlitPatcher
StreamlitPatcher().jupyter()
from openai import OpenAI
import tiktoken
st.title('AI for SaMD')
# Out:
# # AI for SaMD

# %%
openai_api_key = st.sidebar.text_input('OpenAI API Key')

# %%
# Function to count tokens 
def count_tokens(string: str) -> int:
    encoding_name = "p50k_base"
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %%
def generate_response(input_text):
    try:
        llm = OpenAI(temperature=0.7, openai_api_key=openai_api_key)
        response = llm(input_text)
        num_tokens = count_tokens(input_text)
        st.info(f"Input contains {num_tokens} tokens.")
        st.info(response)
    except Exception as e:
        st.error(f"An error occurred: {str(e)}")

# %%
streamlit run llm_app.py
# Out:
#   Cell In[34], line 1
#     streamlit run llm_app.py
#               ^
# SyntaxError: invalid syntax
